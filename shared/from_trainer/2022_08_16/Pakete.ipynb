# %%
L1 = list(range(2, 11))

# %%
L1
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 10]

# %%
L2 = list(range(12, 21))
L2
# Out:
# [12, 13, 14, 15, 16, 17, 18, 19, 20]

# %%
L1 + L2
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 10, 12, 13, 14, 15, 16, 17, 18, 19, 20]

# %%
[x + y for x, y in zip(L1, L2)]
# Out:
# [14, 16, 18, 20, 22, 24, 26, 28, 30]

# %%
def add(seq1, seq2):
    return [x + y for x, y in zip(seq1, seq2)]

# %%
add(L1, L2)
# Out:
# [14, 16, 18, 20, 22, 24, 26, 28, 30]

# %%
# !tree listmath/
# Out:
# listmath/
# ├── __init__.py
# ├── cmath
# │   ├── __init__.py
# │   ├── arithmetics.py
# │   └── trigonometrics.py
# └── math
#     ├── __init__.py
#     ├── arithmetics.py
#     └── trigonometrics.py
#
# 2 directories, 7 files

# %%
import listmath.math.arithmetics

# %%
listmath.math.arithmetics.add(L1, L2)
# Out:
# [14, 16, 18, 20, 22, 24, 26, 28, 30]

# %% [markdown]
# * Modul - `*.py`
# * Paket Verzeichnis mit `__init__.py`

# %%
import listmath

# %%
listmath
# Out:
# <module 'listmath' from '/home/pya_trainer_master/data/listmath/__init__.py'>

# %%
from listmath.math.arithmetics import add

# %%
add is listmath.math.arithmetics.add
# Out:
# True

# %%
from listmath.cmath.arithmetics import add as cadd

# %%
cadd
# Out:
# <function listmath.cmath.arithmetics.add(seq1, seq2)>

# %%
cadd is add
# Out:
# False

# %% [markdown]
# So nicht:
#
# ```python
# from listmath.math.arithmetics import *
# ```

# %%
import numpy as np

# %%
len(dir(np))
# Out:
# 609

# %%
np.sum?

# %%
np
# Out:
# <module 'numpy' from '/opt/mambaforge/envs/python310/lib/python3.10/site-packages/numpy/__init__.py'>

# %%
# !tree /opt/mambaforge/envs/python310/lib/python3.10/site-packages/numpy/
# Out:
# /opt/mambaforge/envs/python310/lib/python3.10/site-packages/numpy/
# ├── LICENSE.txt
# ├── __config__.py
# ├── __init__.cython-30.pxd
# ├── __init__.pxd
# ├── __init__.py
# ├── __init__.pyi
# ├── __pycache__
# │   ├── __config__.cpython-310.pyc
# │   ├── __init__.cpython-310.pyc
# │   ├── _distributor_init.cpython-310.pyc
# │   ├── _globals.cpython-310.pyc
# │   ├── _pytesttester.cpython-310.pyc
# │   ├── _version.cpython-310.pyc
# │   ├── conftest.cpython-310.pyc
# │   ├── ctypeslib.cpython-310.pyc
# │   ├── dual.cpython-310.pyc
# │   ├── matlib.cpython-310.pyc
# │   ├── setup.cpython-310.pyc
# │   └── version.cpython-310.pyc
# ├── _distributor_init.py
# ├── _globals.py
# ├── _pytesttester.py
# ├── _version.py
# ├── char.pyi
# ├── compat
# │   ├── __init__.py
# │   ├── __pycache__
# │   │   ├── __init__.cpython-310.pyc
# │   │   ├── _inspect.cpython-310.pyc
# │   │   ├── py3k.cpython-310.pyc
# │   │   └── setup.cpython-310.pyc
# │   ├── _inspect.py
# │   ├── py3k.py
# ...

# %%
# !tree -I **.pyc /opt/mambaforge/envs/python310/lib/python3.10/site-packages/numpy/
# Out:
# /opt/mambaforge/envs/python310/lib/python3.10/site-packages/numpy/
# ├── LICENSE.txt
# ├── __config__.py
# ├── __init__.cython-30.pxd
# ├── __init__.pxd
# ├── __init__.py
# ├── __init__.pyi
# ├── __pycache__
# ├── _distributor_init.py
# ├── _globals.py
# ├── _pytesttester.py
# ├── _version.py
# ├── char.pyi
# ├── compat
# │   ├── __init__.py
# │   ├── __pycache__
# │   ├── _inspect.py
# │   ├── py3k.py
# │   ├── setup.py
# │   └── tests
# │       ├── __init__.py
# │       ├── __pycache__
# │       └── test_compat.py
# ├── conftest.py
# ├── core
# │   ├── __init__.py
# │   ├── __init__.pyi
# │   ├── __pycache__
# │   ├── _add_newdocs.py
# │   ├── _add_newdocs_scalars.py
# │   ├── _asarray.py
# │   ├── _asarray.pyi
# │   ├── _dtype.py
# │   ├── _dtype_ctypes.py
# │   ├── _exceptions.py
# │   ├── _internal.py
# │   ├── _internal.pyi
# │   ├── _methods.py
# │   ├── _multiarray_tests.cpython-310-x86_64-linux-gnu.so
# │   ├── _multiarray_umath.cpython-310-x86_64-linux-gnu.so
# ...

# %% [markdown]
# # Pause bis 10 Uhr

# %%
import sys

# %%
sys.path
# Out:
# ['/home/pya_trainer_master/data',
#  '/opt/mambaforge/envs/python310/lib/python310.zip',
#  '/opt/mambaforge/envs/python310/lib/python3.10',
#  '/opt/mambaforge/envs/python310/lib/python3.10/lib-dynload',
#  '',
#  '/opt/mambaforge/envs/python310/lib/python3.10/site-packages']

# %%
ls /opt/mambaforge/envs/python310/lib/python3.10/site-packages/*.pth
# Out:
# /opt/mambaforge/envs/python310/lib/python3.10/site-packages/distutils-precedence.pth
# /opt/mambaforge/envs/python310/lib/python3.10/site-packages/matplotlib-3.5.1-py3.10-nspkg.pth

# %%
# %less /opt/mambaforge/envs/python310/lib/python3.10/site-packages/matplotlib-3.5.1-py3.10-nspkg.pth
# Out:
# import sys, types, os;has_mfs = sys.version_info > (3, 5);p = os.path.join(sys._getframe(1).f_locals['sitedir'], *('mpl_toolkits',));importlib = has_mfs and __import__('importlib.util');has_mfs and __import__('importlib.machinery');m = has_mfs and sys.modules.setdefault('mpl_toolkits', importlib.util.module_from_spec(importlib.machinery.PathFinder.find_spec('mpl_toolkits', [os.path.dirname(p)])));m = m or sys.modules.setdefault('mpl_toolkits', types.ModuleType('mpl_toolkits'));mp = (m or []) and m.__dict__.setdefault('__path__',[]);(p not in mp) and mp.append(p)

# %% [markdown]
# # Pause bis 11:55 Uhr

# %%
def append(value, lst=[]):
    lst.append(value)
    return lst

# %%
L = [1, 2, 3]

# %%
append(100, L)
# Out:
# [1, 2, 3, 100]

# %%
L
# Out:
# [1, 2, 3, 100]

# %%
append(10)
# Out:
# [10]

# %%
append(20)
# Out:
# [10, 20]

# %%
def append(value, lst=None):
    if lst is None:
        lst = []
    lst.append(value)
    return lst

# %%
append(10)
# Out:
# [10]

# %%
append(20)
# Out:
# [20]
